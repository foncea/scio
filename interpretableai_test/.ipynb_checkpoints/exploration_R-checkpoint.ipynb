# %%
library(tidyverse)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 4.0.3"
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.0     v purrr   0.3.4
# v tibble  3.0.1     v dplyr   1.0.2
# v tidyr   1.0.2     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.5.0
#
# Warning message:
# "package 'dplyr' was built under R version 4.0.3"
# Warning message:
# "package 'forcats' was built under R version 4.0.2"
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
df = read.csv("../scio_clean_3.csv")

# %%
target = "DXA_densidad"
bin_target = paste(target, "bin", sep="_")

df2 = df %>%
    drop_na() %>%
    group_by(folio) %>%
    summarise(
        !!target := first(get(target)),
        BMI = first(Indice.de.Masa.Corporal),
        copa_sosten = first(copa_sosten),
        across(starts_with("spectrum"), mean), 
        across(starts_with("sample_raw"), mean)
    ) %>%
    mutate(
        !!bin_target := ifelse(get(target) > quantile(get(target), 0.75), "high_density", "low_density"),
        BMI_segment = case_when(
            BMI < quantile(BMI, 0.25) ~ "BMI_1_Quartil",
            BMI < quantile(BMI, 0.5) ~ "BMI_2_Quartil",
            BMI < quantile(BMI, 0.75) ~ "BMI_3_Quartil",
            TRUE ~ "BMI_4_Quartil"
        )
    )
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)

# %%
df2 %>%
    filter(
        get(target) > quantile(get(target), 0.75) | 
        get(target) < quantile(get(target), 0.75)
    ) %>%
    select(- c(target, BMI)) %>%
    pivot_longer(
        cols = !c(!!bin_target, BMI_segment, folio, copa_sosten), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
    group_by(.dots = bin_target, freq, BMI_segment) %>%
    summarize(value = mean(value)) %>%
    ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(bin_target),
#         group = folio
        )
    ) +
    geom_line() +
    facet_wrap(~ BMI_segment)
# Out:
# `summarise()` regrouping output by 'freq', 'BMI_segment' (override with `.groups` argument)
# plot without title

# %%
df2 %>%
    filter(
        spectrum_0 < 0.5 &
        (get(target) > quantile(get(target), 0.75) | 
        get(target) < quantile(get(target), 0.75))
    ) %>%
    select(- target) %>%
    pivot_longer(
        cols = !c(!!bin_target, folio), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
    group_by(.dots = bin_target, freq) %>%
    summarize(value = mean(value)) %>%
    ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(bin_target)
        )
    ) +
    geom_line()
# Out:
# `summarise()` regrouping output by 'freq' (override with `.groups` argument)
# plot without title

# %%
df2 %>%
    filter(
        spectrum_0 < 0.5 &
        (get(target) > quantile(get(target), 0.75) | 
        get(target) < quantile(get(target), 0.75))
    ) %>%
    select(- target) %>%
    pivot_longer(
        cols = !c(!!bin_target, folio), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(
        serie == 'spectrum',
        freq %in% c(50:150, 220:230)
    ) %>%
    ungroup() %>%
    mutate(freq_group = ifelse(freq %in% 50:150, "low_freq", "high_freq")) %>%
    group_by(.dots = bin_target, freq_group, folio) %>%
    summarize(value = mean(value)) %>%
    ungroup() %>%
    ggplot(aes(
        x = freq_group,
        y = value,
        color = get(bin_target),
        group = folio
        )
    ) +
        geom_point()
# Out:
# `summarise()` regrouping output by 'freq_group', 'folio' (override with `.groups` argument)
# plot without title

# %%
df %>%
    group_by(folio) %>%
    summarise(,
              get(target) = )
# Out:
# Note: Using an external vector in selections is ambiguous.
# i Use `all_of(raw_cols)` instead of `raw_cols` to silence this message.
# i See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# `summarise()` ungrouping output (override with `.groups` argument)
#     folio spectrum_0 spectrum_1 spectrum_2 spectrum_3 spectrum_4 spectrum_5
# 1     1   0.5598188  0.5597693  0.5597318  0.5596825  0.5596247  0.5595673
# 2    14   0.5767349  0.5769811  0.5772323  0.5774601  0.5776653  0.5778544
# 3    23   0.5551435  0.5554668  0.5558156  0.5561609  0.5565028  0.5568454
# 4    31   0.3672318  0.3680624  0.3689505  0.3698645  0.3707954  0.3717355
# 5    34   0.5298781  0.5300068  0.5301004  0.5301424  0.5301453  0.5301259
# 6    53   0.3607896  0.3613539  0.3619807  0.3626403  0.3633221  0.3640169
# 7    57   0.5660798  0.5657966  0.5654996  0.5651710  0.5648202  0.5644635
# 8    63   0.3551441  0.3558354  0.3565634  0.3573014  0.3580448  0.3587916
# 9    70   0.2906480  0.2913310  0.2920740  0.2928509  0.2936528  0.2944711
# 10   83   0.6606002  0.6605296  0.6604957  0.6604685  0.6604476  0.6604405
# 11   88   0.4974633  0.4971767  0.4968904  0.4965889  0.4962782  0.4959694
# 12   98   0.4679281  0.4681275  0.4683306  0.4685143  0.4686813  0.4688398
# 13  101   0.6465436  0.6465546  0.6465571  0.6465257  0.6464675  0.6463969
# 14  121   0.3299295  0.3304881  0.3310851  0.3316960  0.3323151  0.3329388
# 15  138   0.3446025  0.3451986  0.3458544  0.3465429  0.3472557  0.3479851
# 16  147   0.3708430  0.3710721  0.3713733  0.3717226  0.3721106  0.3725300
# 17  148   0.2714868  0.2719681  0.2724893  0.2730294  0.2735833  0.2741479
# 18  149   0.2840677  0.2843859  0.2847792  0.2852268  0.2857193  0.2862470
# 19  159   0.3759807  0.3758684  0.3757552  0.3756266  0.3754849  0.3753359
# 20  162   0.3351025  0.3357775  0.3364962  0.3372291  0.3379660  0.3386992
# 21  172   0.6182384  0.6185191  0.6188181  0.6191039  0.6193774  0.6196460
# 22  174   0.3121559  0.3127792  0.3134878  0.3142526  0.3150610  0.3159021
# 23  183   0.4096547  0.4099506  0.4103204  0.4107384  0.4111956  0.4116840
# 29  2.242128       1.963617       1.666383
# 30  2.035556       1.782444       1.512667
# ... ...            ...            ...
# 131 2.045333       1.791111       1.520222
# 132 1.858444       1.627111       1.380444
# 133 2.552609       2.233478       1.895217
# 134 1.993556       1.745778       1.480444
# 135 2.973556       2.601778       2.206889
# 136 1.985870       1.739130       1.476087
# 137 2.196444       1.922667       1.631778
# 138 2.740213       2.397660       2.034468
# 139 1.872600       1.639800       1.391800
# 140 2.072667       1.814000       1.539556
# 141 2.590222       2.267333       1.924000
# 142 2.655319       2.324681       1.971489
# 143 2.022558       1.769302       1.501163
# 144 1.966667       1.721778       1.461778
# 145 2.710222       2.370667       2.012444
# 146 2.085556       1.825111       1.549111
# 147 2.058667       1.803333       1.530444
# 148 2.710667       2.372444       2.012667
# 149 2.868750       2.512292       2.130625
# 150 1.964222       1.720222       1.460000
# 151 2.014667       1.765333       1.498222
# 152 2.136522       1.870435       1.586304
# 153 3.131111       2.741111       2.325556
# 154 2.041111       1.787778       1.516444
# 155 1.964884       1.720465       1.460233
# 156 1.832444       1.602889       1.360000
# 157 2.778444       2.432444       2.063111
# 158 2.000435       1.751957       1.486739
# 159 2.202667       1.928444       1.638000
# 160 1.994889       1.746444       1.482444

# %%
sessionInfo()
# Out:
# R version 4.0.0 (2020-04-24)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 18362)
#
# Matrix products: default
#
# locale:
# [1] LC_COLLATE=Spanish_Chile.1252  LC_CTYPE=Spanish_Chile.1252
# [3] LC_MONETARY=Spanish_Chile.1252 LC_NUMERIC=C
# [5] LC_TIME=Spanish_Chile.1252
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] forcats_0.5.0   stringr_1.4.0   dplyr_1.0.2     purrr_0.3.4
# [5] readr_1.3.1     tidyr_1.0.2     tibble_3.0.1    ggplot2_3.3.0
# [9] tidyverse_1.3.0
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-3     tidyselect_1.1.0 repr_1.1.0       haven_2.3.1
#  [5] colorspace_1.4-1 vctrs_0.3.5      generics_0.0.2   htmltools_0.4.0
#  [9] base64enc_0.1-3  blob_1.2.1       rlang_0.4.8      pillar_1.4.3
# [13] glue_1.4.0       withr_2.2.0      DBI_1.1.0        dbplyr_1.4.4
# [17] modelr_0.1.8     readxl_1.3.1     uuid_0.1-4       lifecycle_0.2.0
# [21] munsell_0.5.0    gtable_0.3.0     cellranger_1.1.0 rvest_0.3.6
# [25] evaluate_0.14    fansi_0.4.1      broom_0.7.0      IRdisplay_0.7.0
# [29] Rcpp_1.0.4.6     backports_1.1.6  scales_1.1.0     IRkernel_1.1
# [33] jsonlite_1.7.1   fs_1.5.0         hms_0.5.3        digest_0.6.27
# [37] stringi_1.4.6    grid_4.0.0       cli_2.0.2        tools_4.0.0
# [41] magrittr_1.5     crayon_1.3.4     pkgconfig_2.0.3  ellipsis_0.3.1
# [45] xml2_1.3.2       reprex_0.3.0     lubridate_1.7.8  assertthat_0.2.1
# [49] httr_1.4.2       rstudioapi_0.11  R6_2.4.1         compiler_4.0.0
