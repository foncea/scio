# %%
library(tidyverse)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 4.0.3"
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.0     v purrr   0.3.4
# v tibble  3.0.1     v dplyr   1.0.2
# v tidyr   1.0.2     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.5.0
#
# Warning message:
# "package 'dplyr' was built under R version 4.0.3"
# Warning message:
# "package 'forcats' was built under R version 4.0.2"
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
df = read.csv("data/scio_dxa_densidad_28_11.csv")

# %%
target = "valor_dxa"
bin_target = paste(target, "bin", sep="_")
s_target = paste(target, '4s', sep="_")

# %%
#Agrupar por folio

df2 = df %>%
    drop_na() %>%
    group_by(folio, mama) %>%
    summarise(
        !!target := mean(get(target)),
        Peso = first(peso),
        edad = first(edad),
        color = first(fitzpatrickcolor),
        BMI = first(indicedemasacorporal),
        copa_sosten = first(copasosten),
        across(starts_with("spectrum"), mean), 
        across(starts_with("sample_raw"), mean)
    ) %>%
    ungroup()

df2 = df2 %>%
    mutate(
        !!bin_target := ifelse(
            get(target) > quantile(get(target), 0.75),
            "high_density",
            "low_density"
        ),
        !!s_target := case_when(
            get(target) >  quantile(get(target), 0.98) ~ paste(quantile(get(target), 0.98)),
            get(target) < quantile(get(target), 0.02) ~ paste(quantile(get(target), 0.02)),
            TRUE ~ 'other'
        ),            
#         BMI_segment = case_when(
#             BMI < quantile(BMI, 0.25) ~ "BMI_1_Quartil",
#             BMI < quantile(BMI, 0.5) ~ "BMI_2_Quartil",
#             BMI < quantile(BMI, 0.75) ~ "BMI_3_Quartil",
#             TRUE ~ "BMI_4_Quartil"
#         ),
        BMI_segment = case_when(
            BMI < 18 ~ "<18",
            BMI < 25 ~ "18-25",
            BMI < 30 ~ "25-30",
            TRUE ~ ">30"
        )
    )
# Out:
# `summarise()` regrouping output by 'folio' (override with `.groups` argument)

# %%
# Agrupar por valor de densidad

df2 %>%
    filter(
        spectrum_0 < 0.9
    ) %>%
    select(- c(target, BMI, Peso)) %>%
    pivot_longer(
        cols = !c(!!bin_target, !!s_target, BMI_segment, folio, copa_sosten, edad), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
#     group_by(.dots = bin_target, freq, BMI_segment) %>%
#     summarize(value = mean(value)) %>%
#     ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(s_target),
        group = folio
        )
    ) +
    geom_line() +
#     facet_wrap(~ ) +
    ggtitle('')
# Out:
# plot without title

# %%
# Histograma de densidad dxa

df2 %>%
    ggplot(aes(x=get(target))) +
    geom_histogram(aes(y=..density..), 
                   bins=25, color='black', fill='white') + 
    geom_density(alpha=.1, fill="#FF6666") + 
    geom_vline(aes(xintercept=quantile(get(target), 0.5)), 
               color="blue", linetype="dashed", size=1) + 
    geom_vline(aes(xintercept=quantile(get(target), 0.75)), 
               color="blue", linetype="dashed", size=1) +
    geom_vline(aes(xintercept=quantile(get(target), 0.25)), 
               color="blue", linetype="dashed", size=1) +
    xlab('Densidad DXA')
# Out:
# plot without title

# %%
# Separar por color

df2 %>%
    filter(
        spectrum_0 < 0.9
    ) %>%
    select(- c(target, BMI, Peso)) %>%
    pivot_longer(
        cols = !c(!!bin_target, !!s_target, BMI_segment, folio, copa_sosten, edad, color), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
#     group_by(.dots = s_target, freq, color) %>%
#     summarize(value = mean(value)) %>%
#     ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(s_target),
        group = folio
        )
    ) +
    geom_line() +
    facet_wrap(~ color)
# Out:
# plot without title

# %%
# Casos extremos

df2 %>%
    filter(
        get(s_target) != 'other'
    ) %>%
    select(- c(target, BMI, Peso)) %>%
    pivot_longer(
        cols = !c(!!bin_target, !!s_target, BMI_segment, folio, copa_sosten, edad, color, mama), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
#     group_by(.dots = s_target, freq, color) %>%
#     summarize(value = mean(value)) %>%
#     ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(s_target),
        group = interaction(folio, mama)
        )
    ) +
    geom_line() +
    facet_wrap(~ color) +
    ggtitle('')
# Out:
# plot without title

# %%
# Variabilidad entre mamas izquierdas

# df2 = df %>%
#   drop_na() %>%
#   filter(mama %in% c('left', 'left_2')) %>%
#   group_by(folio, mama) %>%
#   summarise(
#         !!target := mean(get(target)),
#         across(starts_with("spectrum"), mean),
#     ) %>%
#   ungroup()

# df3 = df2 %>%
#   group_by(folio) %>%
#   summarize(
#     across(starts_with("spectrum"), mean, .names='mean_{.col}'),
#     across(starts_with("spectrum"), sd, .names="sd_{.col}"),
#     across(starts_with("spectrum"), ~ sd(.x) / mean(.x), .names="cv_{.col}")
#   ) %>%
#   ungroup()

# Histogram
# df3 %>%
#   ungroup() %>%
#   rowwise(folio) %>%
#   summarize(mean_cv = mean(c_across(cv_spectrum_0: cv_spectrum_330))) %>%
#   ggplot(aes(x = mean_cv)) +
#     geom_histogram()

df4 = df2 %>%
  pivot_wider(
    id_cols = folio,
    names_from = mama,
    values_from = spectrum_0: spectrum_330
  )
for(i in 0:330){
  df4[, paste("var", i, sep="_")] = (df4[, paste("spectrum", i, "left", sep="_")] / df4[, paste("spectrum", i, "left_2", sep="_")] - 1) * 100
}
# Percentual variation
df4 %>% 
  ungroup() %>%
  rowwise(folio) %>%
  summarize(mean_perc_var = mean(c_across(var_0: var_330))) %>%
  ggplot(aes(x = mean_perc_var)) +
    geom_histogram()
# Out:
# Warning message:
# "Values in `spectrum_0` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_0 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_0 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_0 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_1` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_1 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_1 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_1 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_10` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_10 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_10 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_10 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_100` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_100 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_100 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_100 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_101` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_101 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_101 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_101 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_102` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_102 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_102 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_102 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_103` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_103 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_103 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_103 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_104` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_104 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_104 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_104 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_105` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_105 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_105 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_105 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_106` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_106 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_106 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_106 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_107` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_107 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_107 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_107 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_108` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_108 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_108 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_108 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_109` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_109 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_109 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_109 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_11` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_11 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_11 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_11 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_110` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_110 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_110 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_110 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_111` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_111 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_111 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_111 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_112` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_112 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_112 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_112 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_113` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_113 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_113 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_113 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_114` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_114 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_114 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_114 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_115` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_115 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_115 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_115 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_116` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_116 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_116 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_116 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_117` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_117 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_117 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_117 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_118` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_118 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_118 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_118 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_119` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_119 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_119 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_119 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_12` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_12 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_12 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_12 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_120` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_120 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_120 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_120 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_121` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_121 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_121 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_121 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_122` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_122 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_122 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_122 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_123` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_123 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_123 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_123 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_124` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_124 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_124 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_124 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_125` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_125 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_125 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_125 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_126` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_126 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_126 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_126 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_127` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_127 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_127 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_127 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_128` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_128 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_128 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_128 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_129` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_129 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_129 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_129 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_13` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_13 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_13 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_13 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_130` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_130 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_130 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_130 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_131` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_131 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_131 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_131 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_132` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_132 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_132 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_132 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_133` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_133 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_133 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_133 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_134` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_134 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_134 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_134 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_135` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_135 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_135 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_135 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_136` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_136 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_136 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_136 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_137` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_137 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_137 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_137 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_138` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_138 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_138 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_138 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_139` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_139 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_139 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_139 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_14` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_14 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_14 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_14 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_140` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_140 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_140 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_140 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_141` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_141 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_141 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_141 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_142` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_142 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_142 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_142 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_143` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_143 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_143 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_143 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_144` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_144 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_144 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_144 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_145` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_145 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_145 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_145 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_146` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_146 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_146 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_146 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_147` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_147 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_147 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_147 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_148` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_148 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_148 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_148 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_149` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_149 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_149 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_149 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_15` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_15 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_15 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_15 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_150` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_150 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_150 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_150 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_151` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_151 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_151 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_151 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_152` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_152 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_152 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_152 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_153` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_153 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_153 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_153 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_154` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_154 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_154 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_154 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_155` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_155 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_155 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_155 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_156` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_156 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_156 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_156 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_157` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_157 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_157 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_157 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_158` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_158 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_158 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_158 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_159` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_159 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_159 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_159 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_16` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_16 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_16 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_16 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_160` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_160 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_160 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_160 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_161` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_161 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_161 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_161 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_162` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_162 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_162 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_162 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_163` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_163 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_163 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_163 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_164` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_164 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_164 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_164 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_165` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_165 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_165 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_165 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_166` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_166 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_166 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_166 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_167` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_167 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_167 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_167 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_168` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_168 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_168 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_168 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_169` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_169 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_169 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_169 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_17` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_17 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_17 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_17 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_170` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_170 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_170 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_170 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_171` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_171 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_171 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_171 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_172` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_172 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_172 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_172 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_173` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_173 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_173 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_173 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_174` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_174 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_174 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_174 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_175` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_175 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_175 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_175 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_176` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_176 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_176 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_176 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_177` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_177 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_177 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_177 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_178` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_178 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_178 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_178 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_179` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_179 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_179 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_179 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_18` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_18 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_18 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_18 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_180` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_180 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_180 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_180 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_181` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_181 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_181 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_181 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_182` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_182 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_182 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_182 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_183` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_183 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_183 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_183 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_184` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_184 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_184 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_184 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_185` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_185 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_185 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_185 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_186` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_186 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_186 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_186 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_187` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_187 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_187 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_187 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_188` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_188 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_188 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_188 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_189` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_189 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_189 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_189 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_19` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_19 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_19 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_19 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_190` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_190 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_190 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_190 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_191` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_191 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_191 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_191 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_192` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_192 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_192 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_192 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_193` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_193 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_193 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_193 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_194` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_194 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_194 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_194 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_195` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_195 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_195 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_195 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_196` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_196 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_196 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_196 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_197` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_197 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_197 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_197 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_198` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_198 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_198 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_198 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_199` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_199 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_199 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_199 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_2` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_2 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_2 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_2 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_20` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_20 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_20 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_20 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_200` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_200 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_200 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_200 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_201` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_201 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_201 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_201 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_202` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_202 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_202 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_202 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_203` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_203 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_203 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_203 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_204` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_204 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_204 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_204 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_205` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_205 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_205 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_205 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_206` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_206 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_206 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_206 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_207` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_207 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_207 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_207 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_208` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_208 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_208 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_208 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_209` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_209 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_209 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_209 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_21` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_21 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_21 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_21 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_210` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_210 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_210 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_210 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_211` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_211 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_211 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_211 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_212` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_212 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_212 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_212 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_213` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_213 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_213 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_213 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_214` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_214 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_214 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_214 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_215` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_215 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_215 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_215 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_216` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_216 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_216 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_216 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_217` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_217 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_217 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_217 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_218` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_218 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_218 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_218 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_219` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_219 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_219 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_219 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_22` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_22 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_22 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_22 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_220` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_220 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_220 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_220 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_221` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_221 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_221 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_221 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_222` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_222 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_222 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_222 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_223` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_223 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_223 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_223 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_224` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_224 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_224 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_224 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_225` are not uniquely identified; output will contain list-cols.
# ...
# "Values in `spectrum_57` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_57 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_57 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_57 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_58` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_58 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_58 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_58 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_59` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_59 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_59 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_59 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_6` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_6 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_6 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_6 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_60` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_60 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_60 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_60 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_61` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_61 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_61 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_61 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_62` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_62 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_62 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_62 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_63` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_63 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_63 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_63 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_64` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_64 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_64 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_64 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_65` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_65 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_65 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_65 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_66` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_66 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_66 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_66 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_67` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_67 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_67 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_67 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_68` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_68 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_68 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_68 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_69` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_69 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_69 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_69 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_7` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_7 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_7 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_7 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_70` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_70 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_70 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_70 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_71` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_71 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_71 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_71 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_72` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_72 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_72 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_72 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_73` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_73 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_73 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_73 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_74` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_74 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_74 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_74 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_75` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_75 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_75 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_75 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_76` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_76 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_76 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_76 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_77` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_77 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_77 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_77 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_78` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_78 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_78 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_78 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_79` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_79 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_79 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_79 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_8` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_8 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_8 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_8 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_80` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_80 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_80 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_80 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_81` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_81 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_81 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_81 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_82` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_82 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_82 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_82 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_83` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_83 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_83 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_83 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_84` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_84 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_84 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_84 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_85` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_85 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_85 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_85 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_86` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_86 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_86 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_86 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_87` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_87 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_87 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_87 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_88` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_88 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_88 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_88 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_89` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_89 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_89 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_89 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_9` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_9 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_9 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_9 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_90` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_90 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_90 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_90 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_91` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_91 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_91 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_91 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_92` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_92 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_92 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_92 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_93` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_93 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_93 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_93 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_94` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_94 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_94 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_94 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_95` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_95 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_95 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_95 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_96` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_96 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_96 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_96 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_97` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_97 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_97 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_97 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_98` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_98 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_98 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_98 = summary_fun)` to summarise duplicates"
# Warning message:
# "Values in `spectrum_99` are not uniquely identified; output will contain list-cols.
# * Use `values_fn = list(spectrum_99 = list)` to suppress this warning.
# * Use `values_fn = list(spectrum_99 = length)` to identify where the duplicates arise
# * Use `values_fn = list(spectrum_99 = summary_fun)` to summarise duplicates"
# Error in FUN(left, right): argumento no-numérico para operador binario
# Traceback:
#
# 1. Ops.data.frame(df4[, paste("spectrum", i, "left", sep = "_")],
#  .     df4[, paste("spectrum", i, "left_2", sep = "_")])
# 2. eval(f)
# 3. eval(f)

# %%
# Variabilidad entre mamas izquierdas v2

map_ubicacion = function(x){
  if(grepl('-12', x)){return('12')}
  if(grepl('-3', x)){return('3')}
  if(grepl('-6', x)){return('6')}
  if(grepl('-9', x)){return('9')}
  if(grepl('-Pezon', x)){return('pezon')}
}

# df2 = df %>%
#   drop_na() %>%
#   filter(mama %in% c('left', 'left_2')) %>%
#   mutate(loc = map(ubicacion, map_ubicacion)) %>%
#   filter(loc != 'pezon') %>%
#   group_by(folio, mama, loc) %>%
#   summarise(
#         !!target := mean(get(target)),
#         across(starts_with("spectrum"), mean),
#     ) %>%
#   ungroup() 

# df3 = df2 %>%
#   group_by(folio) %>%
#   summarize(
#     across(starts_with("spectrum"), mean, .names='mean_{.col}'),
#     across(starts_with("spectrum"), sd, .names="sd_{.col}"),
#     across(starts_with("spectrum"), ~ sd(.x) / mean(.x), .names="cv_{.col}")
#   ) %>%
#   ungroup()

# Histogram
# df3 %>%
#   ungroup() %>%
#   rowwise(folio) %>%
#   summarize(mean_cv = mean(c_across(cv_spectrum_0: cv_spectrum_330))) %>%
#   ggplot(aes(x = mean_cv)) +
#     geom_histogram()

# df4 = df2 %>%
#   pivot_wider(
#     id_cols = c(folio, loc),
#     names_from = mama,
#     values_from = spectrum_0: spectrum_330
#   )
# for(i in 0:330){
#   df4[, paste("perc_var", i, sep="_")] = abs((df4[, paste("spectrum", i, "left", sep="_")] / df4[, paste("spectrum", i, "left_2", sep="_")] - 1) * 100)
#   df4[, paste('distance', i, sep="_")] = 2 * (df4[, paste('spectrum', i, 'left', sep="_")] - df4[, paste('spectrum', i, 'left_2', sep="_")]) ^ 2 / ((df4[, paste('spectrum', i, 'left', sep="_")] + df4[, paste('spectrum', i, 'left_2', sep="_")]))
# }

# Percentual variation
df4 %>% 
  ungroup() %>%
  rowwise(folio) %>%
  summarize(mean_perc_var = mean(c_across(where(starts_with('perc_var_'))))) %>%
  ggplot(aes(x = mean_perc_var)) +
    geom_histogram()
# Out:
# Error: Problem with `summarise()` input `mean_perc_var`.
# x Can't convert an integer vector to function
# i Input `mean_perc_var` is `mean(c_across(where(starts_with("perc_var_"))))`.
# i The error occurred in row 1.
# Traceback:
#
# 1. df4 %>% ungroup() %>% rowwise(folio) %>% summarize(mean_perc_var = mean(c_across(where(starts_with("perc_var_"))))) %>%
#  .     ggplot(aes(x = mean_perc_var))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. function_list[[i]](value)
# 8. summarize(., mean_perc_var = mean(c_across(where(starts_with("perc_var_")))))
# 9. summarise.rowwise_df(., mean_perc_var = mean(c_across(where(starts_with("perc_var_")))))
# 10. summarise_cols(.data, ...)
# 11. withCallingHandlers({
#   .     for (i in seq_along(dots)) {
#   .         quo <- dots[[i]]
#   .         chunks[[i]] <- mask$eval_all_summarise(quo)
#   .         mask$across_cache_reset()
#   .         result_type <- types[[i]] <- withCallingHandlers(vec_ptype_common(!!!chunks[[i]]),
#   .             vctrs_error_incompatible_type = function(cnd) {
#   .                 abort(class = "dplyr:::error_summarise_incompatible_combine",
#   .                   parent = cnd)
#   .             })
#   .         if ((is.null(dots_names) || dots_names[i] == "") && is.data.frame(result_type)) {
#   .             map2(seq_along(result_type), names(result_type),
#   .                 function(j, nm) {
#   .                   mask$add(nm, pluck(chunks[[i]], j))
#   .                 })
#   .         }
#   .         else {
#   .             mask$add(auto_named_dots[i], chunks[[i]])
#   .         }
#   .     }
#   .     recycle_info <- .Call(dplyr_summarise_recycle_chunks, chunks,
#   .         mask$get_rows(), types)
#   .     chunks <- recycle_info$chunks
#   .     sizes <- recycle_info$sizes
#   .     for (i in seq_along(dots)) {
#   .         result <- vec_c(!!!chunks[[i]], .ptype = types[[i]])
#   .         if ((is.null(dots_names) || dots_names[i] == "") && is.data.frame(result)) {
#   .             cols[names(result)] <- result
#   .         }
#   .         else {
#   .             cols[[auto_named_dots[i]]] <- result
#   .         }
#   .     }
#   . }, error = function(e) {
#   .     local_call_step(dots = dots, .index = i, .fn = "summarise",
#   .         .dot_data = inherits(e, "rlang_error_data_pronoun_not_found"))
#   .     call_step <- peek_call_step()
#   .     error_name <- call_step$error_name
#   .     if (inherits(e, "dplyr:::error_summarise_incompatible_combine")) {
#   .         bullets <- c(x = glue("Input `{error_name}` must return compatible vectors across groups",
#   .             .envir = peek_call_step()), i = cnd_bullet_combine_details(e$parent$x,
#   .             e$parent$x_arg), i = cnd_bullet_combine_details(e$parent$y,
#   .             e$parent$y_arg))
#   .     }
#   .     else if (inherits(e, "dplyr:::summarise_unsupported_type")) {
#   .         bullets <- c(x = glue("Input `{error_name}` must be a vector, not {friendly_type_of(result)}.",
#   .             result = e$result), i = cnd_bullet_rowwise_unlist())
#   .     }
#   .     else if (inherits(e, "dplyr:::summarise_incompatible_size")) {
#   .         peek_mask()$set_current_group(e$group)
#   .         bullets <- c(x = glue("Input `{error_name}` must be size {or_1(expected_size)}, not {size}.",
#   .             expected_size = e$expected_size, size = e$size),
#   .             i = glue("An earlier column had size {expected_size}.",
#   .                 expected_size = e$expected_size))
#   .     }
#   .     else {
#   .         bullets <- c(x = conditionMessage(e))
#   .     }
#   .     bullets <- c(cnd_bullet_header(), bullets, i = cnd_bullet_input_info())
#   .     if (!inherits(e, "dplyr:::error_summarise_incompatible_combine")) {
#   .         bullets <- c(bullets, i = cnd_bullet_cur_group_label())
#   .     }
#   .     abort(bullets, class = "dplyr_error")
#   . })
# 12. mask$eval_all_summarise(quo)
# 13. mean(c_across(where(starts_with("perc_var_"))))
# 14. c_across(where(starts_with("perc_var_")))
# 15. c_across_setup({
#   .     {
#   .         cols
#   .     }
#   . }, key = key)
# 16. tidyselect::eval_select(expr(!!cols), across_cols)
# 17. eval_select_impl(data, names(data), as_quosure(expr, env), include = include,
#   .     exclude = exclude, strict = strict, name_spec = name_spec,
#   .     allow_rename = allow_rename)
# 18. with_subscript_errors(vars_select_eval(vars, expr, strict, data = x,
#   .     name_spec = name_spec, uniquely_named = uniquely_named, allow_rename = allow_rename,
#   .     type = type), type = type)
# 19. tryCatch(instrument_base_errors(expr), vctrs_error_subscript = function(cnd) {
#   .     cnd$subscript_action <- subscript_action(type)
#   .     cnd$subscript_elt <- "column"
#   .     cnd_signal(cnd)
#   . })
# 20. tryCatchList(expr, classes, parentenv, handlers)
# 21. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 22. doTryCatch(return(expr), name, parentenv, handler)
# 23. instrument_base_errors(expr)
# 24. withCallingHandlers(expr, simpleError = function(cnd) {
#   .     abort(conditionMessage(cnd), parent = cnd)
#   . })
# 25. vars_select_eval(vars, expr, strict, data = x, name_spec = name_spec,
#   .     uniquely_named = uniquely_named, allow_rename = allow_rename,
#   .     type = type)
# 26. walk_data_tree(expr, data_mask, context_mask)
# 27. eval_context(expr, context_mask)
# 28. eval_tidy(expr, context_mask)
# 29. where(starts_with("perc_var_"))
# 30. as_function(fn)
# 31. abort_coercion(x, friendly_type("function"))
# 32. abort(paste0("Can't convert ", x_type, " to ", to_type))
# 33. signal_abort(cnd)
# 34. signalCondition(cnd)
# 35. (function (e)
#   . {
#   .     local_call_step(dots = dots, .index = i, .fn = "summarise",
#   .         .dot_data = inherits(e, "rlang_error_data_pronoun_not_found"))
#   .     call_step <- peek_call_step()
#   .     error_name <- call_step$error_name
#   .     if (inherits(e, "dplyr:::error_summarise_incompatible_combine")) {
#   .         bullets <- c(x = glue("Input `{error_name}` must return compatible vectors across groups",
#   .             .envir = peek_call_step()), i = cnd_bullet_combine_details(e$parent$x,
#   .             e$parent$x_arg), i = cnd_bullet_combine_details(e$parent$y,
#   .             e$parent$y_arg))
#   .     }
#   .     else if (inherits(e, "dplyr:::summarise_unsupported_type")) {
#   .         bullets <- c(x = glue("Input `{error_name}` must be a vector, not {friendly_type_of(result)}.",
#   .             result = e$result), i = cnd_bullet_rowwise_unlist())
#   .     }
#   .     else if (inherits(e, "dplyr:::summarise_incompatible_size")) {
#   .         peek_mask()$set_current_group(e$group)
#   .         bullets <- c(x = glue("Input `{error_name}` must be size {or_1(expected_size)}, not {size}.",
#   .             expected_size = e$expected_size, size = e$size),
#   .             i = glue("An earlier column had size {expected_size}.",
#   .                 expected_size = e$expected_size))
#   .     }
#   .     else {
#   .         bullets <- c(x = conditionMessage(e))
#   .     }
#   .     bullets <- c(cnd_bullet_header(), bullets, i = cnd_bullet_input_info())
#   .     if (!inherits(e, "dplyr:::error_summarise_incompatible_combine")) {
#   .         bullets <- c(bullets, i = cnd_bullet_cur_group_label())
#   .     }
#   .     abort(bullets, class = "dplyr_error")
#   . })(structure(list(message = "Can't convert an integer vector to function",
#   .     trace = structure(list(calls = list(IRkernel::main(), kernel$run(),
#   .         IRkernel:::handle_shell(), executor$execute(msg), base::tryCatch(evaluate(request$content$code,
#   .             envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .             interrupt = function(cond) interrupted <<- TRUE,
#   .             error = .self$handle_error), base:::tryCatchList(expr,
#   .             classes, parentenv, handlers), base:::tryCatchOne(tryCatchList(expr,
#   .             names[-nh], parentenv, handlers[-nh]), names[nh],
#   .             parentenv, handlers[[nh]]), base:::doTryCatch(return(expr),
#   .             name, parentenv, handler), base:::tryCatchList(expr,
#   .             names[-nh], parentenv, handlers[-nh]), base:::tryCatchOne(expr,
#   .             names, parentenv, handlers[[1L]]), base:::doTryCatch(return(expr),
#   .             name, parentenv, handler), evaluate::evaluate(request$content$code,
#   .             envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .         evaluate:::evaluate_call(expr, parsed$src[[i]], envir = envir,
#   .             enclos = enclos, debug = debug, last = i == length(out),
#   .             use_try = stop_on_error != 2L, keep_warning = keep_warning,
#   .             keep_message = keep_message, output_handler = output_handler,
#   .             include_timing = include_timing), evaluate:::timing_fn(handle(ev <- withCallingHandlers(withVisible(eval(expr,
#   .             envir, enclos)), warning = wHandler, error = eHandler,
#   .             message = mHandler))), evaluate:::handle(ev <- withCallingHandlers(withVisible(eval(expr,
#   .             envir, enclos)), warning = wHandler, error = eHandler,
#   .             message = mHandler)), base::try(f, silent = TRUE),
#   .         base::tryCatch(expr, error = function(e) {
#   .             call <- conditionCall(e)
#   .             if (!is.null(call)) {
#   .                 if (identical(call[[1L]], quote(doTryCatch)))
#   .                   call <- sys.call(-4L)
#   .                 dcall <- deparse(call)[1L]
#   .                 prefix <- paste("Error in", dcall, ": ")
#   .                 LONG <- 75L
#   .                 sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#   .                 w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#   .                   type = "w")
#   .                 if (is.na(w))
#   .                   w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#   .                     type = "b")
#   .                 if (w > LONG)
#   .                   prefix <- paste0(prefix, "\n  ")
#   .             }
#   .             else prefix <- "Error : "
#   .             msg <- paste0(prefix, conditionMessage(e), "\n")
#   .             .Internal(seterrmessage(msg[1L]))
#   .             if (!silent && isTRUE(getOption("show.error.messages"))) {
#   .                 cat(msg, file = outFile)
#   .                 .Internal(printDeferredWarnings())
#   .             }
#   .             invisible(structure(msg, class = "try-error", condition = e))
#   .         }), base:::tryCatchList(expr, classes, parentenv, handlers),
#   .         base:::tryCatchOne(expr, names, parentenv, handlers[[1L]]),
#   .         base:::doTryCatch(return(expr), name, parentenv, handler),
#   .         base::withCallingHandlers(withVisible(eval(expr, envir,
#   .             enclos)), warning = wHandler, error = eHandler, message = mHandler),
#   .         base::withVisible(eval(expr, envir, enclos)), base::eval(expr,
#   .             envir, enclos), base::eval(expr, envir, enclos),
#   .         df4 %>% ungroup() %>% rowwise(folio) %>% summarize(mean_perc_var = mean(c_across(where(starts_with("perc_var_"))))) %>%
#   .             ggplot(aes(x = mean_perc_var)), base::withVisible(eval(quote(`_fseq`(`_lhs`)),
#   .             env, env)), base::eval(quote(`_fseq`(`_lhs`)), env,
#   .             env), base::eval(quote(`_fseq`(`_lhs`)), env, env),
#   .         `_fseq`(`_lhs`), magrittr::freduce(value, `_function_list`),
#   .         function_list[[i]](value), dplyr::summarize(., mean_perc_var = mean(c_across(where(starts_with("perc_var_"))))),
#   .         dplyr:::summarise.rowwise_df(., mean_perc_var = mean(c_across(where(starts_with("perc_var_"))))),
#   .         dplyr:::summarise_cols(.data, ...), base::withCallingHandlers({
#   .             for (i in seq_along(dots)) {
#   .                 quo <- dots[[i]]
#   .                 chunks[[i]] <- mask$eval_all_summarise(quo)
#   .                 mask$across_cache_reset()
#   .                 result_type <- types[[i]] <- withCallingHandlers(vec_ptype_common(!!!chunks[[i]]),
#   .                   vctrs_error_incompatible_type = function(cnd) {
#   .                     abort(class = "dplyr:::error_summarise_incompatible_combine",
#   .                       parent = cnd)
#   .                   })
#   .                 if ((is.null(dots_names) || dots_names[i] ==
#   .                   "") && is.data.frame(result_type)) {
#   .                   map2(seq_along(result_type), names(result_type),
#   .                     function(j, nm) {
#   .                       mask$add(nm, pluck(chunks[[i]], j))
#   .                     })
#   .                 }
#   .                 else {
#   .                   mask$add(auto_named_dots[i], chunks[[i]])
#   .                 }
#   .             }
#   .             recycle_info <- .Call(dplyr_summarise_recycle_chunks,
#   .                 chunks, mask$get_rows(), types)
#   .             chunks <- recycle_info$chunks
#   .             sizes <- recycle_info$sizes
#   .             for (i in seq_along(dots)) {
#   .                 result <- vec_c(!!!chunks[[i]], .ptype = types[[i]])
#   .                 if ((is.null(dots_names) || dots_names[i] ==
#   .                   "") && is.data.frame(result)) {
#   .                   cols[names(result)] <- result
#   .                 }
#   .                 else {
#   .                   cols[[auto_named_dots[i]]] <- result
#   .                 }
#   .             }
#   .         }, error = function(e) {
#   .             local_call_step(dots = dots, .index = i, .fn = "summarise",
#   .                 .dot_data = inherits(e, "rlang_error_data_pronoun_not_found"))
#   .             call_step <- peek_call_step()
#   .             error_name <- call_step$error_name
#   .             if (inherits(e, "dplyr:::error_summarise_incompatible_combine")) {
#   .                 bullets <- c(x = glue("Input `{error_name}` must return compatible vectors across groups",
#   .                   .envir = peek_call_step()), i = cnd_bullet_combine_details(e$parent$x,
#   .                   e$parent$x_arg), i = cnd_bullet_combine_details(e$parent$y,
#   .                   e$parent$y_arg))
#   .             }
#   .             else if (inherits(e, "dplyr:::summarise_unsupported_type")) {
#   .                 bullets <- c(x = glue("Input `{error_name}` must be a vector, not {friendly_type_of(result)}.",
#   .                   result = e$result), i = cnd_bullet_rowwise_unlist())
#   .             }
#   .             else if (inherits(e, "dplyr:::summarise_incompatible_size")) {
#   .                 peek_mask()$set_current_group(e$group)
#   .                 bullets <- c(x = glue("Input `{error_name}` must be size {or_1(expected_size)}, not {size}.",
#   .                   expected_size = e$expected_size, size = e$size),
#   .                   i = glue("An earlier column had size {expected_size}.",
#   .                     expected_size = e$expected_size))
#   .             }
#   .             else {
#   .                 bullets <- c(x = conditionMessage(e))
#   .             }
#   .             bullets <- c(cnd_bullet_header(), bullets, i = cnd_bullet_input_info())
#   .             if (!inherits(e, "dplyr:::error_summarise_incompatible_combine")) {
#   .                 bullets <- c(bullets, i = cnd_bullet_cur_group_label())
#   .             }
#   .             abort(bullets, class = "dplyr_error")
#   .         }), mask$eval_all_summarise(quo), base::mean(c_across(where(starts_with("perc_var_")))),
#   .         dplyr::c_across(where(starts_with("perc_var_"))), dplyr:::c_across_setup({
#   .             {
#   .                 cols
#   .             }
#   .         }, key = key), tidyselect::eval_select(expr(!!cols),
#   .             across_cols), tidyselect:::eval_select_impl(data,
#   .             names(data), as_quosure(expr, env), include = include,
#   .             exclude = exclude, strict = strict, name_spec = name_spec,
#   .             allow_rename = allow_rename), tidyselect:::with_subscript_errors(vars_select_eval(vars,
#   .             expr, strict, data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#   .             allow_rename = allow_rename, type = type), type = type),
#   .         base::tryCatch(instrument_base_errors(expr), vctrs_error_subscript = function(cnd) {
#   .             cnd$subscript_action <- subscript_action(type)
#   .             cnd$subscript_elt <- "column"
#   .             cnd_signal(cnd)
#   .         }), base:::tryCatchList(expr, classes, parentenv, handlers),
#   .         base:::tryCatchOne(expr, names, parentenv, handlers[[1L]]),
#   .         base:::doTryCatch(return(expr), name, parentenv, handler),
#   .         tidyselect:::instrument_base_errors(expr), base::withCallingHandlers(expr,
#   .             simpleError = function(cnd) {
#   .                 abort(conditionMessage(cnd), parent = cnd)
#   .             }), tidyselect:::vars_select_eval(vars, expr, strict,
#   .             data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#   .             allow_rename = allow_rename, type = type), tidyselect:::walk_data_tree(expr,
#   .             data_mask, context_mask), tidyselect:::eval_context(expr,
#   .             context_mask), rlang::eval_tidy(expr, context_mask),
#   .         tidyselect:::where(starts_with("perc_var_")), rlang::as_function(fn),
#   .         rlang:::abort_coercion(x, friendly_type("function"))),
#   .         parents = c(0L, 1L, 2L, 3L, 4L, 5L, 6L, 7L, 6L, 9L, 10L,
#   .         4L, 12L, 13L, 13L, 15L, 16L, 17L, 18L, 19L, 13L, 13L,
#   .         13L, 23L, 0L, 25L, 25L, 27L, 28L, 29L, 30L, 31L, 31L,
#   .         33L, 34L, 34L, 0L, 0L, 38L, 39L, 40L, 41L, 42L, 43L,
#   .         44L, 45L, 42L, 47L, 41L, 49L, 50L, 51L, 0L, 53L, 54L),
#   .         indices = 1:55), class = "rlang_trace", version = 1L),
#   .     parent = NULL), class = c("rlang_error", "error", "condition"
#   . )))
# 36. abort(bullets, class = "dplyr_error")
# 37. signal_abort(cnd)

# %%
# Variabilidad dentro de la mama

# df2 = df %>%
#   drop_na() %>%
#   group_by(folio, mama, ubicacion) %>%
#   summarise(
#         !!target := mean(get(target)),
#         across(starts_with("spectrum"), mean),
#     ) %>%
#   ungroup()

# df3 = df2 %>%
#   group_by(folio, mama) %>%
#   summarize(
#     !!target := mean(get(target)),
#     across(starts_with("spectrum"), mean, .names='mean_{.col}'),
#     across(starts_with("spectrum"), sd, .names="sd_{.col}"),
#     across(starts_with("spectrum"), ~ sd(.x) / mean(.x), .names="cv_{.col}")
#   ) %>%
#   ungroup()

# Histogram
# df3 %>%
#   rowwise() %>%
#   summarize(mean_cv = mean(c_across(cv_spectrum_0: cv_spectrum_330))) %>%
#   ggplot(aes(x = mean_cv)) +
#     geom_histogram()

# Scatter plot with dxa/variability of measurements
# df3 %>%
#   rowwise() %>%
#   mutate(mean_cv = mean(c_across(cv_spectrum_0: cv_spectrum_330)),
#          sd_cv = sd(c_across(cv_spectrum_0: cv_spectrum_330))) %>%
#   ungroup() %>%
#   mutate(cv = sd_cv / mean_cv) %>%
#   ggplot(aes(
#     y = cv,
#     x = get(target)
#     )
#   ) +
#   geom_point() +
#   xlab('DXA')

# df3 %>%
#   rowwise() %>%
#   mutate(mean_cv = mean(c_across(cv_spectrum_0: cv_spectrum_330)),
#          sd_cv = sd(c_across(cv_spectrum_0: cv_spectrum_330))) %>%
#   ungroup() %>%
#   mutate(cv = sd_cv / mean_cv) %>%
#   ggplot(aes(
#     y = cv,
#     x = get(target)
#     )
#   ) +
#   geom_point() +
#   xlab('DXA')

df3 %>%
  pivot_longer(
        cols = !c(!!target, folio, mama), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
  mutate(
      serie = str_replace(series, "_.*", ""),
      freq = as.numeric(str_replace(series, ".*_", ""))
  ) %>%
  filter(folio < 40 & serie == 'cv') %>%
  mutate(folio = as.factor(folio)) %>%
  ggplot(aes(
    x = freq,
    y = value,
    color = interaction(folio, mama)
    )
  ) + 
  geom_point() +
  ylab('CV')
# Out:
# plot without title

# %%
df2 %>%
    filter(
        spectrum_0 < 0.5
    ) %>%
    select(- c(target, BMI, Peso)) %>%
    pivot_longer(
        cols = !c(!!bin_target, BMI_segment, folio, copa_sosten, peso_segment, edad), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
    group_by(.dots = bin_target, freq, BMI_segment) %>%
    summarize(value = mean(value)) %>%
    ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(bin_target),
#         group = folio
        )
    ) +
    geom_line() +
    facet_wrap(~ BMI_segment)
# Out:
# `summarise()` regrouping output by 'freq', 'BMI_segment' (override with `.groups` argument)
# plot without title

# %%
df2 %>%
    filter(
        spectrum_0 < 0.5 &
        (get(target) > quantile(get(target), 0.75) | 
        get(target) < quantile(get(target), 0.75))
    ) %>%
    select(- target) %>%
    pivot_longer(
        cols = !c(!!bin_target, folio), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
    group_by(.dots = bin_target, freq) %>%
    summarize(value = mean(value)) %>%
    ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(bin_target)
        )
    ) +
    geom_line()
# Out:
# `summarise()` regrouping output by 'freq' (override with `.groups` argument)
# plot without title

# %%
df2 %>%
    filter(
        spectrum_0 < 0.5 &
        (get(target) > quantile(get(target), 0.75) | 
        get(target) < quantile(get(target), 0.75))
    ) %>%
    select(- target) %>%
    pivot_longer(
        cols = !c(!!bin_target, folio), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(
        serie == 'spectrum',
        freq %in% c(50:150, 220:230)
    ) %>%
    ungroup() %>%
    mutate(freq_group = ifelse(freq %in% 50:150, "low_freq", "high_freq")) %>%
    group_by(.dots = bin_target, freq_group, folio) %>%
    summarize(value = mean(value)) %>%
    ungroup() %>%
    ggplot(aes(
        x = freq_group,
        y = value,
        color = get(bin_target),
        group = folio
        )
    ) +
        geom_point()
# Out:
# `summarise()` regrouping output by 'freq_group', 'folio' (override with `.groups` argument)
# plot without title

# %%
target = "DXA_densidad"
bin_target = paste(target, "bin", sep="_")

df2 = df %>%
    drop_na() %>%
    group_by(folio) %>%
    summarise(
        !!target := first(get(target)),
        Peso = first(Peso),
        edad = first(edad),
        BMI = first(Indice.de.Masa.Corporal),
        copa_sosten = first(copa_sosten),
        across(starts_with("spectrum"), mean), 
        across(starts_with("sample_raw"), mean)
    ) %>%
    mutate(
        !!bin_target := ifelse(get(target) > quantile(get(target), 0.75), "high_density", "low_density"),
        BMI_segment = case_when(
            BMI < 18 ~ "<18",
            BMI < 25 ~ "18-25",
            BMI < 30 ~ "25-30",
            TRUE ~ ">30"
        ),
        peso_segment = case_when(
            Peso < quantile(Peso, 0.25) ~ "peso_1_Quartil",
            Peso < quantile(Peso, 0.5) ~ "peso_2_Quartil",
            Peso < quantile(Peso, 0.75) ~ "peso_3_Quartil",
            TRUE ~ "peso_4_Quartil"
        )
    )
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)

# %%
df2 %>%
    filter(
        get(target) > quantile(get(target), 0.75) | 
        get(target) < quantile(get(target), 0.75)
    ) %>%
    select(- c(target, BMI, Peso)) %>%
    pivot_longer(
        cols = !c(!!bin_target, BMI_segment, folio, copa_sosten, peso_segment, edad), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
#     group_by(.dots = bin_target, freq, BMI_segment) %>%
#     summarize(value = mean(value)) %>%
#     ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(bin_target),
        group = folio
        )
    ) +
    geom_line() +
    facet_wrap(~ BMI_segment)
# Out:
# plot without title

# %%
df2 %>%
    filter(
        spectrum_1 < 0.5
    ) %>%
    select(- c(target, BMI, Peso)) %>%
    pivot_longer(
        cols = !c(!!bin_target, BMI_segment, folio, copa_sosten, peso_segment, edad), 
        names_to = "series",
        values_to = "value",
        values_drop_na = TRUE
    ) %>%
    mutate(
        serie = str_replace(series, "_.*", ""),
        freq = as.numeric(str_replace(series, ".*_", ""))
    ) %>%
    filter(serie == 'spectrum') %>%
    ungroup() %>%
    group_by(.dots = bin_target, freq, BMI_segment) %>%
    summarize(value = mean(value)) %>%
    ungroup()  %>%
    ggplot(aes(
        x = freq, 
        y = value, 
        color = get(bin_target),
#         group = folio
        )
    ) +
    geom_line() +
    facet_wrap(~ BMI_segment)
# Out:
# `summarise()` regrouping output by 'freq', 'BMI_segment' (override with `.groups` argument)
# plot without title

# %%
df2 %>%
    ggplot(aes(x = get(target))) +
    geom_histogram(aes(y=..density..), binwidth=4)+
    geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %%
nrow(df2)
# Out:
# [1] 79
